# %% [markdown]
# # Spencer Chun

# %%
"""Purpose: This program mets m and n 
Programmer: Spencer Chun
Date: 9/19/2025"""
m=1
n=2
m+=10
n+=10
temp = m
m=n
n=temp
print("m =",m)
print("n =",n)
# Out:
# m = 12
# n = 11

# %%
starting_word = "baker"
letters = list(starting_word)
letters[1]="i"
del letters[-1]
letters += ["s"]
print(letters)
# Out:
# ['b', 'i', 'k', 'e', 's']

# %%
inflation = [3.84, -0.36, 1.64, 3.16, 2.07, 1.46, 1.62, 0.12, 1.26, 2.13, 2.44, 1.81, 1.23, 4.70, 8.00, 4.12]
years = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

inflation_dict = dict(zip(years, inflation))
print(inflation_dict[2018])
print("In 2017, the inflation rate was was",inflation_dict[2017],"percent")
# Out:
# 2.44
# In 2017, the inflation rate was was 2.13 percent
